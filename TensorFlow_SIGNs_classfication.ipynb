# %% [markdown]
# ## 1 - Import packages

# %% [markdown]
# **Exercise**: Please mount your Google drive, and set up your working folder here.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# start your code here
os.chdir("/content/drive/MyDrive/DeepLearningInPractice/Homework6") # change your working folder here

# end your code here

# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.framework import ops
from tf_utils import load_dataset, random_mini_batches, convert_to_one_hot, predict

# %matplotlib inline
np.random.seed(123)
tf.random.set_seed(123)

# %% [markdown]
# # 2 - Problem statement: SIGNS Dataset
#
# One afternoon, with some friends we decided to teach our computers to decipher sign language. We spent a few hours taking pictures in front of a white wall and came up with the following dataset. It's now your job to build an algorithm that would facilitate communications from a speech-impaired person to someone who doesn't understand sign language.
#
# - **Training set**: 1080 pictures (64 by 64 pixels) of signs representing numbers from 0 to 5 (180 pictures per number).
# - **Test set**: 120 pictures (64 by 64 pixels) of signs representing numbers from 0 to 5 (20 pictures per number).
#
# Note that this is a subset of the SIGNS dataset. The complete dataset contains many more signs.
#
# Here are examples for each number, and how an explanation of how we represent the labels. These are the original pictures, before we lowered the image resolutoion to 64 by 64 pixels.
# <figure>
# <center>
# <img src='https://drive.google.com/uc?id=1Nuox7mBJMGQt_QXZxmYGkXFEO5mjPf-B' />
# <figcaption>Image Caption</figcaption></center>
# </figure>
#
#
# Run the following code to load the dataset.

# %%
# Loading the dataset
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# %% [markdown]
# Change the index below and run the cell to visualize some examples in the dataset.

# %%
# Example of a picture
index = 44
plt.imshow(X_train_orig[index])
print ("y = " + str(np.squeeze(Y_train_orig[:, index])))
# Out:
# y = 1

# %% [markdown]
# # 3. Using One Hot encodings
#
# Many times in deep learning you will have a y vector with numbers ranging from 0 to C-1, where C is the number of classes. If C is for example 4, then you might have the following y vector which you will need to convert as follows:
# <figure>
# <center>
# <img src='https://drive.google.com/uc?id=1P02l9Fu2flQp0gsRl2bTAm0bsZ2cIMWI' />
# <figcaption>
# </figure>
#
#
#
# This is called a "one hot" encoding, because in the converted representation exactly one element of each column is "hot" (meaning set to 1). In tensorflow, we can tranform the labels of samples to one hot vectors by calling
#
# ```
# tf.keras.utils.to_categorical(y)
# ```
# Please transform the lables (or the output of the dataset) to one hot vectors.

# %% [markdown]
# As usual you flatten the image dataset, then normalize it by dividing by 255. On top of that, you will convert each label to a one-hot vector . Run the cell below to do so.

# %%
# Flatten the training and test images
X_train_flatten = X_train_orig.reshape(X_train_orig.shape[0], -1)
X_test_flatten = X_test_orig.reshape(X_test_orig.shape[0], -1)
# Normalize image vectors
X_train = X_train_flatten/255.
X_test = X_test_flatten/255.
# Flatten the training and test labels
Y_train_flatten=Y_train_orig.flatten()
Y_test_flatten=Y_test_orig.flatten()

# Convert training labels (Y_train_flatten) and test labels (Y_test_flatten) to one hot matrices\
### START CODE HERE ###'
Y_train = tf.keras.utils.to_categorical(Y_train_flatten)
Y_test =tf.keras.utils.to_categorical(Y_test_flatten)
### END CODE HERE ###

print ("number of training examples = " + str(X_train.shape[1]))
print ("number of test examples = " + str(X_test.shape[1]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 12288
# number of test examples = 12288
# X_train shape: (1080, 12288)
# Y_train shape: (1080, 6)
# X_test shape: (120, 12288)
# Y_test shape: (120, 6)

# %% [markdown]
# **Note** that 12288 comes from $64 \times 64 \times 3$. Each image is square, 64 by 64 pixels, and 3 is for the RGB colors. Please make sure all these shapes make sense to you before continuing.

# %% [markdown]
# #4.Building your model
#
# **Your goal** is to build an model capable of recognizing a sign with high accuracy. To do so, you are going to build a tensorflow model that is almost the same as one you have previously built for cat recognition and multi-class classification problems. If you already forget previous homeworks, please go back to review them to get some clues.
#
# **Previous related homeworks**
#
# "Planar_data_tensorflow.ipynb" in Homework 2
#
# "deepNN_tensorflow.ipynb" in Homework 3
#
# "regularized_deepNN_tensorflow.ipynb" in Homework 4
#
# "batch-size-test-student-version.ipynb" In Homework 5

# %%
### START CODE HERE ###
model=tf.keras.Sequential([
    #Input layer                      
    tf.keras.layers.Input(shape=(12288)), # Set how many elements are there in every training image?

    #Start adding hidden layers  
    tf.keras.layers.Dense(100), # Please set your neuron numbers, activation function and so on. 

    #please feel free to add more hidden layers here. 
    #tf.keras.layers.Dense(50),
    #tf.keras.layers.Dense(50),
    # End adding hidden layers 

    #output layer                   
    tf.keras.layers.Dense(6, activation='softmax') # Set how many elements are there in every training output
            
])
### END CODE HERE ###'
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 100)               1228900
#
#  dense_7 (Dense)             (None, 6)                 606
#
# =================================================================
# Total params: 1,229,506
# Trainable params: 1,229,506
# Non-trainable params: 0
# _________________________________________________________________

# %%
### START CODE HERE ###'
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),  # Optimizer. Please change 'None' to some meaningful learning rate which is usually <1
              loss=tf.keras.losses.BinaryCrossentropy(), # loss. Please change 'None' to some meaningful loss
              # List of metrics to monitor
              metrics=['accuracy'],
                 )
### END CODE HERE ###'

# %%
### START CODE HERE ###'
history = model.fit(
    X_train , #  training input data
    Y_train, # training output data
    batch_size=500, # how many samples (points) do you want to use to update weights once? 
    epochs=100 # how many iterations do you want to train your model? Your data will be reused to train the model for the number of epochs. I trained 5 min for this model
)
### END CODE HERE ###'
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0799 - accuracy: 0.9565
# Epoch 2/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0786 - accuracy: 0.9546
# Epoch 3/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0810 - accuracy: 0.9528
# Epoch 4/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0777 - accuracy: 0.9611
# Epoch 5/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0825 - accuracy: 0.9593
# Epoch 6/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0796 - accuracy: 0.9546
# Epoch 7/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0853 - accuracy: 0.9481
# Epoch 8/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0799 - accuracy: 0.9593
# Epoch 9/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0785 - accuracy: 0.9528
# Epoch 10/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0832 - accuracy: 0.9491
# Epoch 11/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0837 - accuracy: 0.9472
# Epoch 12/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0794 - accuracy: 0.9556
# Epoch 13/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0795 - accuracy: 0.9574
# Epoch 14/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0840 - accuracy: 0.9491
# Epoch 15/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0810 - accuracy: 0.9537
# Epoch 16/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0824 - accuracy: 0.9537
# Epoch 17/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0791 - accuracy: 0.9556
# Epoch 18/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0775 - accuracy: 0.9546
# Epoch 19/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0759 - accuracy: 0.9602
# Epoch 20/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0784 - accuracy: 0.9556
# Epoch 21/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0775 - accuracy: 0.9556
# Epoch 22/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0781 - accuracy: 0.9583
# Epoch 23/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0776 - accuracy: 0.9565
# Epoch 24/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0759 - accuracy: 0.9593
# Epoch 25/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0763 - accuracy: 0.9583
# Epoch 26/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0757 - accuracy: 0.9630
# Epoch 27/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0753 - accuracy: 0.9630
# Epoch 28/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0751 - accuracy: 0.9620
# Epoch 29/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0764 - accuracy: 0.9583
# Epoch 30/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0759 - accuracy: 0.9574
# Epoch 31/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0759 - accuracy: 0.9648
# Epoch 32/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0763 - accuracy: 0.9648
# Epoch 33/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0778 - accuracy: 0.9620
# Epoch 34/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0776 - accuracy: 0.9556
# Epoch 35/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0797 - accuracy: 0.9574
# Epoch 36/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0788 - accuracy: 0.9593
# Epoch 37/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0775 - accuracy: 0.9574
# Epoch 38/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0781 - accuracy: 0.9574
# Epoch 39/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0767 - accuracy: 0.9611
# Epoch 40/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0760 - accuracy: 0.9593
# Epoch 41/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0752 - accuracy: 0.9667
# Epoch 42/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0762 - accuracy: 0.9537
# Epoch 43/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0753 - accuracy: 0.9611
# Epoch 44/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0739 - accuracy: 0.9639
# Epoch 45/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0751 - accuracy: 0.9667
# Epoch 46/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0740 - accuracy: 0.9620
# Epoch 47/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0748 - accuracy: 0.9593
# Epoch 48/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0744 - accuracy: 0.9639
# Epoch 49/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0759 - accuracy: 0.9620
# Epoch 50/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0770 - accuracy: 0.9611
# Epoch 51/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0743 - accuracy: 0.9602
# Epoch 52/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0750 - accuracy: 0.9639
# Epoch 53/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0747 - accuracy: 0.9611
# Epoch 54/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0738 - accuracy: 0.9602
# Epoch 55/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0765 - accuracy: 0.9620
# Epoch 56/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0746 - accuracy: 0.9630
# Epoch 57/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0750 - accuracy: 0.9602
# Epoch 58/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0740 - accuracy: 0.9685
# Epoch 59/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0754 - accuracy: 0.9611
# Epoch 60/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0738 - accuracy: 0.9611
# Epoch 61/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0739 - accuracy: 0.9676
# Epoch 62/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0734 - accuracy: 0.9676
# Epoch 63/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0737 - accuracy: 0.9611
# Epoch 64/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0741 - accuracy: 0.9630
# Epoch 65/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0727 - accuracy: 0.9602
# Epoch 66/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0724 - accuracy: 0.9667
# Epoch 67/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0730 - accuracy: 0.9639
# Epoch 68/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0720 - accuracy: 0.9630
# Epoch 69/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0740 - accuracy: 0.9657
# Epoch 70/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0720 - accuracy: 0.9648
# Epoch 71/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0729 - accuracy: 0.9648
# Epoch 72/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0725 - accuracy: 0.9676
# Epoch 73/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0727 - accuracy: 0.9657
# Epoch 74/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0722 - accuracy: 0.9648
# Epoch 75/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0729 - accuracy: 0.9676
# Epoch 76/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0712 - accuracy: 0.9648
# Epoch 77/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0721 - accuracy: 0.9639
# Epoch 78/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0739 - accuracy: 0.9648
# Epoch 79/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0737 - accuracy: 0.9583
# Epoch 80/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0714 - accuracy: 0.9685
# Epoch 81/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0719 - accuracy: 0.9639
# Epoch 82/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0731 - accuracy: 0.9639
# Epoch 83/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0718 - accuracy: 0.9657
# Epoch 84/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0734 - accuracy: 0.9648
# Epoch 85/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0723 - accuracy: 0.9676
# Epoch 86/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0746 - accuracy: 0.9583
# Epoch 87/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0712 - accuracy: 0.9639
# Epoch 88/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0702 - accuracy: 0.9648
# Epoch 89/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0707 - accuracy: 0.9667
# Epoch 90/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0696 - accuracy: 0.9685
# Epoch 91/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0715 - accuracy: 0.9639
# Epoch 92/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0709 - accuracy: 0.9667
# Epoch 93/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0718 - accuracy: 0.9667
# Epoch 94/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0705 - accuracy: 0.9667
# Epoch 95/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0713 - accuracy: 0.9657
# Epoch 96/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0701 - accuracy: 0.9694
# Epoch 97/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0701 - accuracy: 0.9667
# Epoch 98/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0697 - accuracy: 0.9657
# Epoch 99/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0694 - accuracy: 0.9704
# Epoch 100/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0708 - accuracy: 0.9676

# %% [markdown]
# **If the training works, congratulations! You have built a model for recognizing SIGN language.**

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss','val_loss'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-6f36883ea1df> in <module>()
#       1 plt.figure()
#       2 plt.plot(history.history['loss'])
# ----> 3 plt.plot(history.history['val_loss'])
#       4 plt.legend(['loss','val_loss'])
#
# KeyError: 'val_loss'

# %%
model.evaluate(X_test,Y_test)
# Out:
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1796 - accuracy: 0.8333
# [0.17962613701820374, 0.8333333134651184]

# %% [markdown]
# # 5. Grading rule
#
# ***Try your best to achieve high accuarcy.  The grade for this homework will based on your model final training accurracy and test accuracy. ***
#
# For example, if your final training accurracy is 87.8 (consider one decimal) and test accuracy is 70.9, the total grade is 8.78 + 7.09 =15.87. The full credit is 10+10 =20.  It is hard to get full credit in this homework, please try your best.

# %% [markdown]
# **Tips**
#
# You can try to improve its accuracy by:
# 1. tuning the hyperparameters (learning rate, batch size, epoches and so on)
# 2. adjusting your layers numbers or nuron numbers.
# 3. changing optimizer or loss function
# 4. using dropout layer
# 5. add regularizers.L2
# 6. .....

# %% [markdown]
# Once again, here's a thumbs up for your work!

# %%
# %pylab inline
import matplotlib.image as mpimg
img = mpimg.imread('images/thumbs_up.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
