# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir("/content/drive/MyDrive/DeepLearningInPractice/Mid_term")
# Out:
# Mounted at /content/drive

# %%
#Load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##1. Introduction
# The company seeks to automate (in real time) the loan qualifying procedure based on information given by customers while filling out an online application form. It is expected that the development of deep learning models that can help the company predict loan approval in accelerating decision-making process for determining whether an applicant is eligible for a loan or not.

# %% [markdown]
# ##2. Data analysis
# These details are Gender, Marital Status, Education, Number of Dependents, Income, Loan Amount, Credit History and others. To automate this process, they have given a problem to identify the customers segments, those are eligible for loan amount so that they can specifically target these customers. Here they have provided a partial data set.
#
# We first load the loan data. Please print out the shape of 'loan_data'.

# %%
#Load dataset
loan_data=pd.read_csv('loan.csv')

# start your code here
n_record,n_category=loan_data.shape
# end your code here
print('There are %d records.' % n_record)
print('Every record has %d categories' % n_category)
# Out:
# There are 614 records.
# Every record has 13 categories

# %% [markdown]
# Expected output:
#
# ```
# There are 614 records.
# Every record has 13 categories
# ```
#
# Now, let's print the 1st 20 records of the loan data, and have a better understanding of what the data look like.

# %%
loan_data.head(20)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# 13  LP001029    Male      No          0      Graduate            No
# 14  LP001030    Male     Yes          2      Graduate            No
# 15  LP001032    Male      No          0      Graduate            No
# 16  LP001034    Male      No          1  Not Graduate            No
# 17  LP001036  Female      No          0      Graduate            No
# 18  LP001038    Male     Yes          0  Not Graduate            No
# 19  LP001041    Male     Yes          0      Graduate           NaN
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              5849                0.0         NaN             360.0
# 1              4583             1508.0       128.0             360.0
# 2              3000                0.0        66.0             360.0
# 3              2583             2358.0       120.0             360.0
# 4              6000                0.0       141.0             360.0
# 5              5417             4196.0       267.0             360.0
# 6              2333             1516.0        95.0             360.0
# 7              3036             2504.0       158.0             360.0
# 8              4006             1526.0       168.0             360.0
# 9             12841            10968.0       349.0             360.0
# 10             3200              700.0        70.0             360.0
# 11             2500             1840.0       109.0             360.0
# 12             3073             8106.0       200.0             360.0
# 13             1853             2840.0       114.0             360.0
# 14             1299             1086.0        17.0             120.0
# 15             4950                0.0       125.0             360.0
# 16             3596                0.0       100.0             240.0
# 17             3510                0.0        76.0             360.0
# 18             4887                0.0       133.0             360.0
# 19             2600             3500.0       115.0               NaN
#
#     Credit_History Property_Area Loan_Status
# 0              1.0         Urban           Y
# 1              1.0         Rural           N
# 2              1.0         Urban           Y
# 3              1.0         Urban           Y
# 4              1.0         Urban           Y
# 5              1.0         Urban           Y
# 6              1.0         Urban           Y
# 7              0.0     Semiurban           N
# 8              1.0         Urban           Y
# 9              1.0     Semiurban           N
# 10             1.0         Urban           Y
# 11             1.0         Urban           Y
# 12             1.0         Urban           Y
# 13             1.0         Rural           N
# 14             1.0         Urban           Y
# 15             1.0         Urban           Y
# 16             NaN         Urban           Y
# 17             0.0         Urban           N
# 18             1.0         Rural           N
# 19             1.0         Urban           Y

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# We can see that there are 13 categories in the records. Please pay close attention to the data. Sometimes, there are `NaN` values. We will need to fix this later. Right now, Let's analyze the categories one by one.

# %% [markdown]
# ###2.1 Loan ID
# Loan ID is our 1st category. However, this category has no relevance to the approval status. Therefore, we will drop this category. Please print out the first 5 records of the 'loan_data' to make sure that the category 'Loan_ID' is dropped. Hint: check cells above to see how we print the first 20 records.

# %%
loan_data = loan_data.drop(['Loan_ID'], axis = 1)

#start your code here
loan_data.head(5)
# end your code here
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# 4         Urban           Y

# %% [markdown]
# Expected output:
# ![alt text](https://drive.google.com/uc?id=1F8Lve6Wx6lYuoMPCNaq_cLEzT1dY9Z__)

# %% [markdown]
# ### 2.2 Gender
# We would like to know among all these 614 records, how many of them are male, how many of them are female, how many of them are null entries.

# %%
gender_count=loan_data.Gender.value_counts(dropna=False) # count different values in 'Gender' category
print(gender_count)
sns.countplot(x="Gender", data=loan_data, palette="hls")
plt.show()

p_male=gender_count['Male']/n_record
p_female=gender_count['Female']/n_record
p_NaN=gender_count[-1]/n_record

print('Percentage of Male: {:.2f}%'.format(p_male*100))
print('Percentage of Female: {:.2f}%'.format(p_female*100))
print('Percentage of missing value: {:.2f}%'.format(p_NaN*100))
# Out:
# Male      489
# Female    112
# NaN        13
# Name: Gender, dtype: int64
# Percentage of Male: 79.64%
# Percentage of Female: 18.24%
# Percentage of missing value: 2.12%

# %% [markdown]
# Conclusion: There are much more male applicants than female applicants. The missing value takes 2.12% of the records, a small portion of the whole records.

# %% [markdown]
# ### 2.3 Married
# Please follow the same idea in section 2.2 to analyze the category 'Married' and make a conclusion at the end of this section.

# %%
# start your code here
married_count=loan_data.Married.value_counts(dropna=False) # count different values in 'Gender' category
print(married_count)
sns.countplot(x="Married", data=loan_data, palette="hls")
plt.show()

p_male=married_count['Yes']/n_record
p_female=married_count['No']/n_record
p_NaN=married_count[-1]/n_record

print('Percentage of Married: {:.2f}%'.format(p_male*100))
print('Percentage of un-married: {:.2f}%'.format(p_female*100))
print('Percentage of missing value: {:.2f}%'.format(p_NaN*100))

# end your code here
# Out:
# Yes    398
# No     213
# NaN      3
# Name: Married, dtype: int64
# Percentage of Married: 64.82%
# Percentage of un-married: 34.69%
# Percentage of missing value: 0.49%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1GbYJ8nHEgGximpRJMJFwQP4bIiP-luPN)
#
# Please make your conclusion here.

# %% [markdown]
# ###2.4 Dependents
#
# Please follow the same idea in section 2.2 to analyze the category 'Dependents' and make a conclusion at the end of this section.

# %%
# start your code here
Dependents_count=loan_data.Dependents.value_counts(dropna=False) # count different values in 'Gender' category
print(Dependents_count)
sns.countplot(x="Dependents", data=loan_data, palette="hls")
plt.show()

p_0=Dependents_count['0']/n_record
p_1=Dependents_count['1']/n_record
p_2=Dependents_count['2']/n_record
p_3=Dependents_count['3+']/n_record

p_NaN=Dependents_count[-1]/n_record

print('Percentage of 0  dependant: {:.2f}%'.format(p_0*100))
print('Percentage of 1  dependant: {:.2f}%'.format(p_1*100))
print('Percentage of 2  dependant: {:.2f}%'.format(p_2*100))
print('Percentage of 3  dependant: {:.2f}%'.format(p_3*100))

print('Percentage of missing value: {:.2f}%'.format(p_NaN*100))

# end your code here
# Out:
# 0      345
# 1      102
# 2      101
# 3+      51
# NaN     15
# Name: Dependents, dtype: int64
# Percentage of 0  dependant: 56.19%
# Percentage of 1  dependant: 16.61%
# Percentage of 2  dependant: 16.45%
# Percentage of 3  dependant: 8.31%
# Percentage of missing value: 2.44%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1T05UzKCRuFpxUY4EJKzOZ-MQgFfSsR0v)
#
# Please make your conclusion here.

# %% [markdown]
# ### 2.5 Education
#
# Please follow the same idea in section 2.2 to analyze the category 'Education' and make a conclusion at the end of this section.

# %%
# start your code here
Education_count=loan_data.Education.value_counts(dropna=False) # count different values in 'Gender' category
print(Education_count)
sns.countplot(x="Education", data=loan_data, palette="hls")
plt.show()

p_male=Education_count['Graduate']/n_record
p_female=Education_count['Not Graduate']/n_record
p_NaN=Education_count[-1]/n_record

print('Percentage of Graduate: {:.2f}%'.format(p_male*100))
print('Percentage of Not Graduate: {:.2f}%'.format(p_female*100))
#print('Percentage of missing value: {:.2f}%'.format(p_NaN*100))

# end your code here
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
# Percentage of Graduate: 78.18%
# Percentage of Not Graduate: 21.82%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1uAg12JNPRvQCVZd6tPtYfUZH9Qqs4AR5)
#
# Please make your conclusion here.

# %% [markdown]
# ### 2.6 Self_Employed
#
# Please follow the same idea in section 2.2 to analyze the category 'Self_Employed' and make a conclusion at the end of this section.

# %%
# start your code here
Self_Employed_count=loan_data.Self_Employed.value_counts(dropna=False) # count different values in 'Gender' category
print(Self_Employed_count)
sns.countplot(x="Self_Employed", data=loan_data, palette="hls")
plt.show()

p_male=Self_Employed_count['Yes']/n_record
p_female=Self_Employed_count['No']/n_record
p_NaN=Self_Employed_count[-1]/n_record

print('Percentage of Graduate: {:.2f}%'.format(p_male*100))
print('Percentage of Not Graduate: {:.2f}%'.format(p_female*100))
print('Percentage of missing value: {:.2f}%'.format(p_NaN*100))

# end your code here
# Out:
# No     500
# Yes     82
# NaN     32
# Name: Self_Employed, dtype: int64
# Percentage of Graduate: 13.36%
# Percentage of Not Graduate: 81.43%
# Percentage of missing value: 5.21%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1SLZFuBWQpXL62a9ppu9i8An4WDruJOmi)
#
# Please make your conclusion here.

# %% [markdown]
# ### 2.7 Applicant income
# The applicant income has a large range of values, and the previous analysis method doesn't apply well in this case. We will use histogram to characterize the distribution of the income.
#
# From the plot, we can see that the income of most applicants are below $10,000, and are not evenly distributed. Normalization is definitly needed for this category.
#
# Besides, the distribution has a thin but long right tail. We will need to treat the right tail to make the distribution more concentrated.

# %%
sns.histplot(loan_data['ApplicantIncome'])
plt.show()

# %% [markdown]
# ### 2.8 Coapplicant income
# Please use the same technique in Section 2.7 to analyze the distribution of the 'CoapplicantIncome' and give a brief discussion of it.

# %%
# start your code here
sns.histplot(loan_data['CoapplicantIncome'])
plt.show()
# end your code here

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1Phqf9WgoHK6OZBuLLWhb8cexvn1bzqye)
#
# Discussion here:

# %% [markdown]
# ### 2.9 Loan amount
#
# Please use the same technique in Section 2.7 to analyze the distribution of the 'LoanAmount' and give a brief discussion of it.

# %%
# start your code here
# start your code here
sns.histplot(loan_data['LoanAmount'])
plt.show()
# end your code here
# end your code here

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1THtXJXErj8rMLcLMVAc1GIsInRajueKG)
#
# Discussion here:

# %% [markdown]
# ### 2.10 Loan_amount_term
#
# Please use the same technique in Section 2.7 to analyze the distribution of the 'Loan_Amount_Term	' and give a brief discussion of it.

# %%
# start your code here
# start your code here
sns.histplot(loan_data['Loan_Amount_Term'])
plt.show()
# end your code here
# end your code here

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1UTKNr75TQKF626JWvAJJ6ItM_dgw3R2J)
#
# Discussion here:

# %% [markdown]
# ### 2.11 Credit history
#
# Please follow the same technique in section 2.7 to analyze the category 'Credit_History' and give a grief discusion.

# %%
# start your code here
sns.histplot(loan_data['Credit_History'])
plt.show()
# end your code here

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1O03n_ZcFpIsr-lubli-g_IPwL6ZhGpr0)
#
# Discussion here:

# %% [markdown]
# ### 2.12 Property area
#
# Please follow the same technique in section 2.2 to analyze the category 'Property_Area' and give a grief discusion.

# %%
# start your code here
Property_Area_count=loan_data.Property_Area.value_counts(dropna=False) # count different values in 'Gender' category
print(Property_Area_count)
sns.countplot(x="Property_Area", data=loan_data, palette="hls")
plt.show()

p_0=Property_Area_count['Urban']/n_record
p_1=Property_Area_count['Rural']/n_record
p_2=Property_Area_count['Semiurban']/n_record


p_NaN=Dependents_count[-1]/n_record

print('Percentage of 0  Urban: {:.2f}%'.format(p_0*100))
print('Percentage of 1  Rural: {:.2f}%'.format(p_1*100))
print('Percentage of 2  Semiurban: {:.2f}%'.format(p_2*100))


print('Percentage of missing value: {:.2f}%'.format(p_NaN*100))
# end your code here
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64
# Percentage of 0  Urban: 32.90%
# Percentage of 1  Rural: 29.15%
# Percentage of 2  Semiurban: 37.95%
# Percentage of missing value: 2.44%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1ZQ0MRWAMe4fFTn9bF-M8ttIVDlJ1kysC)
#
# Discussion here:

# %% [markdown]
# ###2.13 Loan Status
# Please follow the same technique in section 2.2 to analyze the category 'Loan_Status' and give a grief discusion.

# %%
# start your code here
Loan_Status_count=loan_data.Loan_Status.value_counts(dropna=False) # count different values in 'Gender' category
print(Loan_Status_count)
sns.countplot(x="Loan_Status", data=loan_data, palette="hls")
plt.show()

p_male=Loan_Status_count['Y']/n_record
p_female=Loan_Status_count['N']/n_record
p_NaN=Loan_Status_count[-1]/n_record

print('Percentage of YES: {:.2f}%'.format(p_male*100))
print('Percentage of NO: {:.2f}%'.format(p_female*100))
#print('Percentage of missing value: {:.2f}%'.format(p_NaN*100))

# end your code here
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64
# Percentage of YES: 68.73%
# Percentage of NO: 31.27%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1KByUcd1F74SAneDWcUgj9_8Vbb-pOGz3)
#
# Discussion here:

# %% [markdown]
# ## 3. Data preprocessing
#
# ### 3.1 Data imputation

# %%
# Checking Null Values.
loan_data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# There are missing values in Gender, Married, Dependents, Self_Employed, LoanAmount, Loan_Amount_Term, and Credit_History features.
# We will treat the missing values in all the features one by one.
# We can consider these methods to fill the missing values:
#
# * For numerical variables: imputation using mean or median
# * For categorical variables: imputation using mode
#
# There are very few missing values in Gender, Married, Dependents, Credit_History, and Self_Employed features so we can fill them using the mode of the features.
#
# The imputation of 'Gender' is given. Please use the same command to fill the missing values in category 'Married', 'Dependents', 'Self_Employed', and 'Credit_History'.

# %%
loan_data['Gender'].fillna(loan_data['Gender'].mode()[0], inplace=True)
# start your code here
loan_data['Married'].fillna(loan_data['Married'].mode()[0], inplace=True)
loan_data['Dependents'].fillna(loan_data['Dependents'].mode()[0], inplace=True)
loan_data['Credit_History'].fillna(loan_data['Credit_History'].mode()[0], inplace=True)
loan_data['Self_Employed'].fillna(loan_data['Self_Employed'].mode()[0], inplace=True)



# start your code here
# end your code here

# %% [markdown]
# For numerical variables like LoanAmount and Loan_Amount_Term, we fill the missing values with their medians. The imputation of 'Loan_Amount_Term' is given. Please use the same command to fill the missing values in category 'LoanAmount'.

# %%
loan_data['Loan_Amount_Term'].fillna(loan_data['Loan_Amount_Term'].median(),inplace = True)
# start your code here
loan_data['LoanAmount'].fillna(loan_data['LoanAmount'].median(),inplace = True)
# end your code here

# %% [markdown]
# Now, let's print out the data to see whether we fill the missing values with reasonable values. You can compare the table below with the table in the beginning to see the differences.

# %%
loan_data.head(20)
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male      No          0      Graduate            No             5849
# 1     Male     Yes          1      Graduate            No             4583
# 2     Male     Yes          0      Graduate           Yes             3000
# 3     Male     Yes          0  Not Graduate            No             2583
# 4     Male      No          0      Graduate            No             6000
# 5     Male     Yes          2      Graduate           Yes             5417
# 6     Male     Yes          0  Not Graduate            No             2333
# 7     Male     Yes         3+      Graduate            No             3036
# 8     Male     Yes          2      Graduate            No             4006
# 9     Male     Yes          1      Graduate            No            12841
# 10    Male     Yes          2      Graduate            No             3200
# 11    Male     Yes          2      Graduate            No             2500
# 12    Male     Yes          2      Graduate            No             3073
# 13    Male      No          0      Graduate            No             1853
# 14    Male     Yes          2      Graduate            No             1299
# 15    Male      No          0      Graduate            No             4950
# 16    Male      No          1  Not Graduate            No             3596
# 17  Female      No          0      Graduate            No             3510
# 18    Male     Yes          0  Not Graduate            No             4887
# 19    Male     Yes          0      Graduate            No             2600
#
#     CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                 0.0       128.0             360.0             1.0
# 1              1508.0       128.0             360.0             1.0
# 2                 0.0        66.0             360.0             1.0
# 3              2358.0       120.0             360.0             1.0
# 4                 0.0       141.0             360.0             1.0
# 5              4196.0       267.0             360.0             1.0
# 6              1516.0        95.0             360.0             1.0
# 7              2504.0       158.0             360.0             0.0
# 8              1526.0       168.0             360.0             1.0
# 9             10968.0       349.0             360.0             1.0
# 10              700.0        70.0             360.0             1.0
# 11             1840.0       109.0             360.0             1.0
# 12             8106.0       200.0             360.0             1.0
# 13             2840.0       114.0             360.0             1.0
# 14             1086.0        17.0             120.0             1.0
# 15                0.0       125.0             360.0             1.0
# 16                0.0       100.0             240.0             1.0
# 17                0.0        76.0             360.0             0.0
# 18                0.0       133.0             360.0             1.0
# 19             3500.0       115.0             360.0             1.0
#
#    Property_Area Loan_Status
# 0          Urban           Y
# 1          Rural           N
# 2          Urban           Y
# 3          Urban           Y
# 4          Urban           Y
# 5          Urban           Y
# 6          Urban           Y
# 7      Semiurban           N
# 8          Urban           Y
# 9      Semiurban           N
# 10         Urban           Y
# 11         Urban           Y
# 12         Urban           Y
# 13         Rural           N
# 14         Urban           Y
# 15         Urban           Y
# 16         Urban           Y
# 17         Urban           N
# 18         Rural           N
# 19         Urban           Y

# %% [markdown]
# Please check whether all missing values are filled using the command `loan_data.isnull().sum()`. If you have all '0' entries, congratulations! You have finished the data imputation.

# %%
loan_data.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# Expected output:
# ```
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64
# ```

# %% [markdown]
# ### 3.2 Converting categorical values to numbers
#
# Let's first take a look at the data type of the loan data.

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    object
#  1   Married            614 non-null    object
#  2   Dependents         614 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      614 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 57.7+ KB

# %% [markdown]
# From the information provided above, we see that the data type of 7 categories is object. We need to convert them to numbers to train our model.
#
# * For 'Gender' category, 'Male' is mapped to 0, 'Female' is mapped to 1.
#
# Please use the same technique to do the following conversion.
#
# * For 'Married', 'Self_Employed', and 'Loan_Status' category, please map 'No' to 0 and 'Yes' to 1.
#
# * For 'Dependents' category, please map '0' to 0, '1' to 1, '2' to 2, and '3+' to 3.
#
# * For 'Education' category, please map 'Graduate' to 1 and 'Not Graduate' to 0.
#
# * For 'Property_Area' category, please map 'Rural' to 0, 'Semiurban' to 1, and 'Urban' to 2.

# %%
# Converting the categories into numbers using map function.
loan_data['Gender'] = loan_data['Gender'].map({'Male': 0, 'Female': 1})

# start your code here
loan_data['Married'] = loan_data['Married'].map({'No': 0, 'Yes': 1})

loan_data['Self_Employed'] = loan_data['Self_Employed'].map({'No': 0, 'Yes': 1})
loan_data['Loan_Status'] = loan_data['Loan_Status'].map({'N': 0, 'Y': 1})

loan_data['Dependents'] = loan_data['Dependents'].map({'0': 0, '1': 1, '2': 2, '3+': 3})
loan_data['Education'] = loan_data['Education'].map({'Graduate': 1, 'Not Graduate': 0})
loan_data['Property_Area'] = loan_data['Property_Area'].map({'Rural': 0, 'Semiurban': 1, 'Urban': 2})

# end your code here

# %% [markdown]
# Now, let's double check the data types to make sure that we have all numerical entries.

# %%
loan_data.head(20)
# Out:
#     Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0        0        0           0          1              0             5849
# 1        0        1           1          1              0             4583
# 2        0        1           0          1              1             3000
# 3        0        1           0          0              0             2583
# 4        0        0           0          1              0             6000
# 5        0        1           2          1              1             5417
# 6        0        1           0          0              0             2333
# 7        0        1           3          1              0             3036
# 8        0        1           2          1              0             4006
# 9        0        1           1          1              0            12841
# 10       0        1           2          1              0             3200
# 11       0        1           2          1              0             2500
# 12       0        1           2          1              0             3073
# 13       0        0           0          1              0             1853
# 14       0        1           2          1              0             1299
# 15       0        0           0          1              0             4950
# 16       0        0           1          0              0             3596
# 17       1        0           0          1              0             3510
# 18       0        1           0          0              0             4887
# 19       0        1           0          1              0             2600
#
#     CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                 0.0       128.0             360.0             1.0
# 1              1508.0       128.0             360.0             1.0
# 2                 0.0        66.0             360.0             1.0
# 3              2358.0       120.0             360.0             1.0
# 4                 0.0       141.0             360.0             1.0
# 5              4196.0       267.0             360.0             1.0
# 6              1516.0        95.0             360.0             1.0
# 7              2504.0       158.0             360.0             0.0
# 8              1526.0       168.0             360.0             1.0
# 9             10968.0       349.0             360.0             1.0
# 10              700.0        70.0             360.0             1.0
# 11             1840.0       109.0             360.0             1.0
# 12             8106.0       200.0             360.0             1.0
# 13             2840.0       114.0             360.0             1.0
# 14             1086.0        17.0             120.0             1.0
# 15                0.0       125.0             360.0             1.0
# 16                0.0       100.0             240.0             1.0
# 17                0.0        76.0             360.0             0.0
# 18                0.0       133.0             360.0             1.0
# 19             3500.0       115.0             360.0             1.0
#
#     Property_Area  Loan_Status
# 0               2            1
# 1               0            0
# 2               2            1
# 3               2            1
# 4               2            1
# 5               2            1
# 6               2            1
# 7               1            0
# 8               2            1
# 9               1            0
# 10              2            1
# 11              2            1
# 12              2            1
# 13              0            0
# 14              2            1
# 15              2            1
# 16              2            1
# 17              2            0
# 18              0            0
# 19              2            1

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int64
#  1   Married            614 non-null    int64
#  2   Dependents         614 non-null    int64
#  3   Education          614 non-null    int64
#  4   Self_Employed      614 non-null    int64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    int64
#  11  Loan_Status        614 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 57.7 KB

# %% [markdown]
# Expected output:
#
# ```
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int64
#  1   Married            614 non-null    int64
#  2   Dependents         614 non-null    int64
#  3   Education          614 non-null    int64
#  4   Self_Employed      614 non-null    int64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    int64
#  11  Loan_Status        614 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 57.7 KB
# ```

# %% [markdown]
# ### 3.3 Right tail treatment
# From section 2.7, 2.8, and 2.9, we see that the income of applicants, coapplicants, and the loan amount have long and thin right tail.
#
# It can be seen that having long and thin right tail often has a significant effect on the mean and standard deviation and hence affecting the distribution. We must take steps to remove the tails from our data sets.
#
# This is called right skewness. One way to remove the skewness is by doing the log transformation. As we take the log transformation, it does not affect the smaller values much but reduces the larger values. So, we get a distribution similar to normal distribution.
# Let’s visualize the effect of log transformation.
#
# Originally, the distribution of applicant income is as below.
#
# ![alt text](https://drive.google.com/uc?id=1UfnWuvx4SV0VLIm5cv0cR1zGteB2g199)
#
# We will apply log transformation to the 'ApplicantIncome' category and recheck the distribution to see the difference.

# %%
epsilon=1
loan_data['ApplicantIncome']=np.log(epsilon+loan_data['ApplicantIncome'])
sns.histplot(loan_data['ApplicantIncome'])
plt.show()

# %% [markdown]
# After the tail treatment, the distribution looks more like a normal distribution. It gives a good base for the next step: data normalization.
#
# Please use the same methods to treat the tails in 'CoapplicantIncome' and 'LoanAmount' category.

# %%
# start your code here
loan_data['CoapplicantIncome']=np.log(epsilon+loan_data['CoapplicantIncome'])
sns.histplot(loan_data['CoapplicantIncome'])
plt.show()

loan_data['LoanAmount']=np.log(epsilon+loan_data['LoanAmount'])
sns.histplot(loan_data['LoanAmount'])
plt.show()
# end your code here

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=11JyrjdzswoYkblgYxm8vvD5KssQmxkyw)

# %% [markdown]
# ### 3.4 Other data preprocessing
#
# We emphasized a lot that you will need to preprocess your data before using them to train your model. Now, please think about whether there are other preprocessing that you can do to help you train a good model. If yes, please do it here.

# %%
# start your code here

loan_data['Loan_Amount_Term']=np.log(epsilon+loan_data['Loan_Amount_Term'])
sns.histplot(loan_data['Loan_Amount_Term'])
plt.show()

loan_data['Credit_History']=np.log(epsilon+loan_data['Credit_History'])
sns.histplot(loan_data['Credit_History'])
plt.show()
# end your code here
loan_data.shape
# Out:
# (614, 13)

# %% [markdown]
# ### 3.5 Correlation among different categories
#
# Now let’s look at the correlation between all the numerical variables. We will use the heat map to visualize the correlation. Heatmaps visualize data through variations in coloring. The variables with darker color means their correlation is more.

# %%
plt.figure(figsize=(15,10))
sns.heatmap(loan_data.corr(), vmax=.8, cmap='BuPu',annot=True, fmt='.2g')

# %% [markdown]
# We see a strong correlation between 'Credit_History' and 'Loan_Status', 'LoanAmount' and 'ApplicantIncome', 'CoapplicantIncome' and 'Married', a strong reverse correlation between 'ApplicantIncome' and 'CoapplicantIncom'. When we choose the categories for the training input, these are all elements that need to be considered.

# %% [markdown]
# ### 3.6 Input and output data splitting
#
# We need to predict the 'Loan_Status'. So, our output is 'Loan_Status'. For the input, you can choose as many  relavant categories as you like.
#
# The output data is seperated. As neural network only accept float as the training data set, we use `np.float32` to change the data type to float.
#
# Please choose your input categories using the similar ideas.

# %%
#array = loan_data.values
Y = np.float32(loan_data[['Loan_Status']].values)
# start your code here
X = np.float32(loan_data[['Credit_History']].values)
# end your code here
X.dtype
# Out:
# dtype('float32')

# %% [markdown]
# Expected output:
# ```
# dtype('float32')
# ```

# %% [markdown]
# ### 3.7 Training and testing data splitting
#
# In our lecture, we mentioned that if you have a small dataset (<2000 samples). It is suggested to use 20% of it for testing purpose. It can be easily realized using sklearn library.

# %%
from sklearn import model_selection
x_train, x_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.2, random_state=1234)

# %% [markdown]
# ## 4 Building Neural network
#
# Please use what we learned before to build your neural network. You have the freedome to choose your network structure. Just keep it in mind that the number of neurons in the input layer and the output layer should be the same as the size of your input and output data for each sample. Besides, since this is a binary classification problem, the activation function in the output layer needs to be 'sigmoid' function.

# %%
import tensorflow as tf

# start your code here
model=tf.keras.Sequential([
    #Input layer                      
    tf.keras.layers.Input(shape=(1)), # Set how many elements are there in every training image?

    #Start adding hidden layers  
    tf.keras.layers.Dense(100, activation='sigmoid'), # Please set your neuron numbers, activation function and so on. 

    #please feel free to add more hidden layers here. 
    tf.keras.layers.Dense(50, activation='sigmoid'),
    tf.keras.layers.Dense(50, activation='sigmoid'),
    # End adding hidden layers 

    #output layer                   
    tf.keras.layers.Dense(1, activation='sigmoid') # Set how many elements are there in every training output
            
])

# end your code here
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 100)               200
#
#  dense_16 (Dense)            (None, 50)                5050
#
#  dense_17 (Dense)            (None, 50)                2550
#
#  dense_18 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 7,851
# Trainable params: 7,851
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 5. Compiling and training your neural network
# Please use what you learned before to compile and train your neural network.

# %%
### START CODE HERE ###'
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),  # Optimizer. Please change 'None' to some meaningful learning rate which is usually <1
              loss=tf.keras.losses.BinaryCrossentropy(), # loss. Please change 'None' to some meaningful loss
              # List of metrics to monitor
              metrics=['accuracy'],
                 )
### END CODE HERE ###'

# %%
history = model.fit(
    x_train, # input data
    y_train, # real output data
    batch_size=300,
    epochs = 200
)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 1s 8ms/step - loss: 0.6209 - accuracy: 0.6884
# Epoch 2/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6217 - accuracy: 0.6884
# Epoch 3/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6203 - accuracy: 0.6884
# Epoch 4/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6199 - accuracy: 0.6884
# Epoch 5/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6205 - accuracy: 0.6884
# Epoch 6/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6207 - accuracy: 0.6884
# Epoch 7/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6202 - accuracy: 0.6884
# Epoch 8/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6198 - accuracy: 0.6884
# Epoch 9/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6198 - accuracy: 0.6884
# Epoch 10/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6199 - accuracy: 0.6884
# Epoch 11/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6196 - accuracy: 0.6884
# Epoch 12/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6195 - accuracy: 0.6884
# Epoch 13/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6194 - accuracy: 0.6884
# Epoch 14/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6195 - accuracy: 0.6884
# Epoch 15/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6195 - accuracy: 0.6884
# Epoch 16/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6194 - accuracy: 0.6884
# Epoch 17/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6192 - accuracy: 0.6884
# Epoch 18/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6191 - accuracy: 0.6884
# Epoch 19/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6190 - accuracy: 0.6884
# Epoch 20/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6190 - accuracy: 0.6884
# Epoch 21/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6190 - accuracy: 0.6884
# Epoch 22/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6192 - accuracy: 0.6884
# Epoch 23/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6187 - accuracy: 0.6884
# Epoch 24/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6188 - accuracy: 0.6884
# Epoch 25/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6185 - accuracy: 0.6884
# Epoch 26/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6186 - accuracy: 0.6884
# Epoch 27/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6188 - accuracy: 0.6884
# Epoch 28/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6183 - accuracy: 0.6884
# Epoch 29/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6183 - accuracy: 0.6884
# Epoch 30/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6182 - accuracy: 0.6884
# Epoch 31/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6182 - accuracy: 0.6884
# Epoch 32/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6179 - accuracy: 0.6884
# Epoch 33/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6179 - accuracy: 0.6884
# Epoch 34/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6178 - accuracy: 0.6884
# Epoch 35/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6176 - accuracy: 0.6884
# Epoch 36/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6174 - accuracy: 0.6884
# Epoch 37/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6172 - accuracy: 0.6884
# Epoch 38/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6170 - accuracy: 0.6884
# Epoch 39/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6171 - accuracy: 0.6884
# Epoch 40/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6174 - accuracy: 0.6884
# Epoch 41/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6168 - accuracy: 0.6884
# Epoch 42/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6163 - accuracy: 0.6884
# Epoch 43/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6166 - accuracy: 0.6884
# Epoch 44/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6165 - accuracy: 0.6884
# Epoch 45/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6164 - accuracy: 0.6884
# Epoch 46/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6160 - accuracy: 0.6884
# Epoch 47/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6156 - accuracy: 0.6884
# Epoch 48/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6153 - accuracy: 0.6884
# Epoch 49/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6153 - accuracy: 0.6884
# Epoch 50/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6151 - accuracy: 0.6884
# Epoch 51/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6148 - accuracy: 0.6884
# Epoch 52/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6146 - accuracy: 0.6884
# Epoch 53/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6143 - accuracy: 0.6884
# Epoch 54/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6142 - accuracy: 0.6884
# Epoch 55/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6138 - accuracy: 0.6884
# Epoch 56/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6136 - accuracy: 0.6884
# Epoch 57/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6130 - accuracy: 0.6884
# Epoch 58/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6126 - accuracy: 0.6884
# Epoch 59/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6123 - accuracy: 0.6884
# Epoch 60/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6124 - accuracy: 0.6884
# Epoch 61/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6117 - accuracy: 0.6884
# Epoch 62/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6111 - accuracy: 0.6884
# Epoch 63/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6108 - accuracy: 0.6884
# Epoch 64/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6104 - accuracy: 0.6884
# Epoch 65/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6099 - accuracy: 0.6884
# Epoch 66/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6092 - accuracy: 0.6884
# Epoch 67/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.6087 - accuracy: 0.6884
# Epoch 68/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6093 - accuracy: 0.6884
# Epoch 69/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6075 - accuracy: 0.6884
# Epoch 70/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6077 - accuracy: 0.6884
# Epoch 71/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6069 - accuracy: 0.6884
# Epoch 72/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6058 - accuracy: 0.6884
# Epoch 73/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.6052 - accuracy: 0.6884
# Epoch 74/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6046 - accuracy: 0.6884
# Epoch 75/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6040 - accuracy: 0.6884
# Epoch 76/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.6028 - accuracy: 0.6884
# Epoch 77/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6019 - accuracy: 0.6884
# Epoch 78/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.6014 - accuracy: 0.6884
# Epoch 79/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6005 - accuracy: 0.6884
# Epoch 80/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.5992 - accuracy: 0.6884
# Epoch 81/200
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5983 - accuracy: 0.6884
# Epoch 82/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5973 - accuracy: 0.6884
# Epoch 83/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5963 - accuracy: 0.6884
# Epoch 84/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5948 - accuracy: 0.6884
# Epoch 85/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5934 - accuracy: 0.6884
# Epoch 86/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5929 - accuracy: 0.6884
# Epoch 87/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5908 - accuracy: 0.6884
# Epoch 88/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5894 - accuracy: 0.6884
# Epoch 89/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5879 - accuracy: 0.6884
# Epoch 90/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5864 - accuracy: 0.6884
# Epoch 91/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5848 - accuracy: 0.6884
# Epoch 92/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.5833 - accuracy: 0.6884
# Epoch 93/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.5812 - accuracy: 0.6884
# Epoch 94/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5796 - accuracy: 0.6884
# Epoch 95/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5787 - accuracy: 0.6884
# Epoch 96/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5760 - accuracy: 0.6884
# Epoch 97/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5743 - accuracy: 0.6884
# Epoch 98/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5724 - accuracy: 0.6884
# Epoch 99/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5700 - accuracy: 0.6884
# Epoch 100/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5679 - accuracy: 0.6884
# Epoch 101/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5662 - accuracy: 0.6884
# Epoch 102/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5648 - accuracy: 0.6884
# Epoch 103/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5621 - accuracy: 0.6884
# Epoch 104/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5595 - accuracy: 0.6884
# Epoch 105/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5573 - accuracy: 0.6884
# Epoch 106/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5557 - accuracy: 0.7312
# Epoch 107/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5531 - accuracy: 0.7963
# Epoch 108/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5503 - accuracy: 0.7963
# Epoch 109/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5490 - accuracy: 0.7963
# Epoch 110/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5466 - accuracy: 0.7963
# Epoch 111/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5444 - accuracy: 0.7963
# Epoch 112/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5418 - accuracy: 0.7963
# Epoch 113/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5400 - accuracy: 0.7963
# Epoch 114/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5385 - accuracy: 0.7963
# Epoch 115/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5355 - accuracy: 0.7963
# Epoch 116/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5336 - accuracy: 0.7963
# Epoch 117/200
# 2/2 [==============================] - 0s 24ms/step - loss: 0.5328 - accuracy: 0.7963
# Epoch 118/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5297 - accuracy: 0.7963
# Epoch 119/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.5294 - accuracy: 0.7963
# Epoch 120/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5270 - accuracy: 0.7963
# Epoch 121/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5253 - accuracy: 0.7963
# Epoch 122/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5236 - accuracy: 0.7963
# Epoch 123/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5214 - accuracy: 0.7963
# Epoch 124/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5204 - accuracy: 0.7963
# Epoch 125/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5193 - accuracy: 0.7963
# Epoch 126/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5169 - accuracy: 0.7963
# Epoch 127/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5185 - accuracy: 0.7963
# Epoch 128/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.5163 - accuracy: 0.7963
# Epoch 129/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5153 - accuracy: 0.7963
# Epoch 130/200
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5140 - accuracy: 0.7963
# Epoch 131/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5116 - accuracy: 0.7963
# Epoch 132/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5109 - accuracy: 0.7963
# Epoch 133/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5102 - accuracy: 0.7963
# Epoch 134/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5091 - accuracy: 0.7963
# Epoch 135/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5084 - accuracy: 0.7963
# Epoch 136/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5079 - accuracy: 0.7963
# Epoch 137/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5070 - accuracy: 0.7963
# Epoch 138/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5073 - accuracy: 0.7963
# Epoch 139/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5062 - accuracy: 0.7963
# Epoch 140/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5059 - accuracy: 0.7963
# Epoch 141/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.5056 - accuracy: 0.7963
# Epoch 142/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.5054 - accuracy: 0.7963
# Epoch 143/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5041 - accuracy: 0.7963
# Epoch 144/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5046 - accuracy: 0.7963
# Epoch 145/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5037 - accuracy: 0.7963
# Epoch 146/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5032 - accuracy: 0.7963
# Epoch 147/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5034 - accuracy: 0.7963
# Epoch 148/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5028 - accuracy: 0.7963
# Epoch 149/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5037 - accuracy: 0.7963
# Epoch 150/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5038 - accuracy: 0.7963
# Epoch 151/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5038 - accuracy: 0.7963
# Epoch 152/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5024 - accuracy: 0.7963
# Epoch 153/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5040 - accuracy: 0.7963
# Epoch 154/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5022 - accuracy: 0.7963
# Epoch 155/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5028 - accuracy: 0.7963
# Epoch 156/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5031 - accuracy: 0.7963
# Epoch 157/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5025 - accuracy: 0.7963
# Epoch 158/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5012 - accuracy: 0.7963
# Epoch 159/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5011 - accuracy: 0.7963
# Epoch 160/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5010 - accuracy: 0.7963
# Epoch 161/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5014 - accuracy: 0.7963
# Epoch 162/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5008 - accuracy: 0.7963
# Epoch 163/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5009 - accuracy: 0.7963
# Epoch 164/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5011 - accuracy: 0.7963
# Epoch 165/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5006 - accuracy: 0.7963
# Epoch 166/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5011 - accuracy: 0.7963
# Epoch 167/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.5009 - accuracy: 0.7963
# Epoch 168/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5014 - accuracy: 0.7963
# Epoch 169/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5013 - accuracy: 0.7963
# Epoch 170/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5010 - accuracy: 0.7963
# Epoch 171/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.5007 - accuracy: 0.7963
# Epoch 172/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5007 - accuracy: 0.7963
# Epoch 173/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5006 - accuracy: 0.7963
# Epoch 174/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5006 - accuracy: 0.7963
# Epoch 175/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5009 - accuracy: 0.7963
# Epoch 176/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5002 - accuracy: 0.7963
# Epoch 177/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5010 - accuracy: 0.7963
# Epoch 178/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.5006 - accuracy: 0.7963
# Epoch 179/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5003 - accuracy: 0.7963
# Epoch 180/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.5008 - accuracy: 0.7963
# Epoch 181/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5002 - accuracy: 0.7963
# Epoch 182/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5004 - accuracy: 0.7963
# Epoch 183/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5010 - accuracy: 0.7963
# Epoch 184/200
# 2/2 [==============================] - 0s 19ms/step - loss: 0.5004 - accuracy: 0.7963
# Epoch 185/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5006 - accuracy: 0.7963
# Epoch 186/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.5013 - accuracy: 0.7963
# Epoch 187/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4996 - accuracy: 0.7963
# Epoch 188/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5007 - accuracy: 0.7963
# Epoch 189/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5022 - accuracy: 0.7963
# Epoch 190/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5008 - accuracy: 0.7963
# Epoch 191/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5027 - accuracy: 0.7963
# Epoch 192/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5006 - accuracy: 0.7963
# Epoch 193/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.5002 - accuracy: 0.7963
# Epoch 194/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5009 - accuracy: 0.7963
# Epoch 195/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5008 - accuracy: 0.7963
# Epoch 196/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5009 - accuracy: 0.7963
# Epoch 197/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5003 - accuracy: 0.7963
# Epoch 198/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5009 - accuracy: 0.7963
# Epoch 199/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5004 - accuracy: 0.7963
# Epoch 200/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4999 - accuracy: 0.7963

# %% [markdown]
# Let's take a look at the training history. You probably will need to adjust the parameters like learning rate, batch size, epochs, or even your NN structure.

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
model.evaluate(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-cdedd39be758> in <module>()
#       1 # summarize history for loss
#       2 plt.plot(history.history['loss'])
# ----> 3 plt.plot(history.history['val_loss'])
#       4 plt.title('model loss')
#       5 plt.ylabel('loss')
#
# KeyError: 'val_loss'

# %% [markdown]
# After several adjustion, the results may be still unsatisfying. In this case you will need to take a closer look at your prediction and the true value to see where the problems are. Please manually examine what the mistakes are, and use the technique we learned in the most recent 2 weeks to make some synthetic data to help improve your accuracy in Section 3.4. As a reference, the best accuracy that I can find online using NN is 80%. I was able to improve it to 82.5%. See how accurate you can achieve.

# %%
# Getting predictions for the test set
output = model.predict(x_test)
threshold=0.5
y_pred = np.where(output>=threshold,1,0)
print((y_pred==y_test).sum()/len(y_test))
# Getting accuracy score
for i in range(len(x_test)):
  if y_pred[i,:]<y_test[i,:]:
    print(y_test[i,:],y_pred[i,:],output[i,:], x_test[i,:])
# Out:
# 0.8617886178861789
