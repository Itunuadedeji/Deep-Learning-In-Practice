# %% [markdown]
# # Image Application: cat or not?
#
# **After this assignment you will be able to:**
# - Build and apply a deep neural network to supervised learning.
# - Learn how to do data normalization
# - learn how to do weight initialization
# - Learn how to use regularization
#
# Let's get started!

# %% [markdown]
# ## 1 - Packages

# %% [markdown]
# **Exercise**: Please mount your Google drive, and set up your working folder here.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# start your code here
os.chdir('/content/drive/MyDrive/DeepLearningInPractice/Homework3') # change your working folder here
# end your code here

# %% [markdown]
# Let's first import all the packages that you will need during this assignment.
# - [numpy](https://www.numpy.org/) is the fundamental package for scientific computing with Python.
# - [matplotlib](http://matplotlib.org) is a library to plot graphs in Python.
# - [h5py](http://www.h5py.org) is a common package to interact with a dataset that is stored on an H5 file.
# - [PIL](http://www.pythonware.com/products/pil/) and [scipy](https://www.scipy.org/) are used here to test your model with your own picture at the end.
# - dnn_app_utils provides the customized functions that will be used in this notebook.
# - np.random.seed(1) is used to keep all the random function calls consistent. It will help us grade your work.

# %%
import time
import numpy as np
import tensorflow as tf
import h5py
import matplotlib.pyplot as plt
import dnn_app_utils_v3 as du
from skimage.transform import rescale, resize, downscale_local_mean

# refresh 'planar_utils' module
import imp
imp.reload(du)

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

np.random.seed(1)
tf.random.set_seed(1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 2 - Dataset
#
# **Problem Statement**: You are given a dataset ("data.h5") containing:
#     - a training set of m_train images labelled as cat (1) or non-cat (0)
#     - a test set of m_test images labelled as cat and non-cat
#     - each image is of shape (num_px, num_px, 3) where 3 is for the 3 channels (RGB).
#
# Let's get more familiar with the dataset. Load the data by running the cell below.
#
# The training input and output are stored in 'train_x_orig' and 'train_y'. The test input and output are stored in 'test_x_orig' and 'test_y'.

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = du.load_data()
#print(classes)

# %% [markdown]
# The following code will show you an image in the dataset. Feel free to change the index and re-run the cell multiple times to see other images.

# %%
# Example of a picture
index = 200
plt.imshow(train_x_orig[index])
print("y = " + str(train_y[index,0]) + ". It's a " + classes[train_y[index,0]].decode("utf-8") +  " picture.")
#print(train_x_orig[index].shape,train_x_orig[index])
# Out:
# y = 1. It's a cat picture.

# %% [markdown]
# Let's explore more about the training data. We are curious about the shape of each image and can use 'train_x_orig[index].shape' to expore it.
# **Exercise**: Can you tell what the pixel number of each image is?

# %%
# Explore your dataset 
image_shape=train_x_orig[index].shape
print("Each image is of size: ", image_shape)
#start your code here
num_px=64   # the number of pixels in each column of the image. Hint: The 1st element in image_shape indicates this number?
#end your code here
print('Number of pixels in each column of the image:', num_px)
# Out:
# Each image is of size:  (64, 64, 3)
# Number of pixels in each column of the image: 64

# %% [markdown]
# We just take a close look at an image of the image set. Now, let's take a look at the whole training set.
#
# **Exercise**: The first 4 lines in the following cell print out the shape of the trining images. There are 209 images, and each image has 64 by 64 pixcels and GRB color.
#
# Please print out the shape of the test input (stored in `test_x_orig`) and output (stored in `test_y`) data, and tell how many images we have in the test data.

# %%
train_x_shape=train_x_orig.shape
m_train = train_x_shape[0]
print ("train_x_orig shape: ",train_x_shape)
print ("Number of training examples: " ,m_train)
# start your code here
test_x_shape=test_x_orig.shape
test_y_shape=test_y.shape
m_test = test_x_orig.shape[0]
# end your code here

print ("test_x_orig shape: " ,test_x_shape)
print ("test_y shape: " , test_y_shape)
print ("Number of test examples: " ,m_test)
# Out:
# train_x_orig shape:  (209, 64, 64, 3)
# Number of training examples:  209
# test_x_orig shape:  (50, 64, 64, 3)
# test_y shape:  (50, 1)
# Number of test examples:  50

# %% [markdown]
# As mentioned in our lecture, you reshape and standardize the images before feeding them to the network. The code is given in the cell below.
#
# ![alt text](https://drive.google.com/uc?id=12XXwVJpcT-moegSdzejC-W-hD79qDSk9)
# <caption><center> <u>Figure 1</u>: Image to vector conversion. <br> </center></caption>

# %%
# Reshape the training and test examples 
train_x_flatten = train_x_orig.reshape(train_x_shape[0], -1)   # The "-1" makes reshape flatten the remaining dimensions
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1)

# %% [markdown]
# Data normalization can help us accelerate the training process. The RGB values of an image are integers in the range of [0,255]. We can normalize the training images to have the feature values between 0 and 1 by using `train_x = train_x_flatten/255.0`.
#
# **Exercise**: We normalize the training images using `train_x = train_x_flatten/255.0` in the 1st line. Please normalize the test images to have feature values between 0 and 1.

# %%
# Standardize data to have feature values between 0 and 1.
train_x = train_x_flatten/255.0

#start your code here
test_x = test_x_flatten/255.0
#end your code here

print ("train_x's shape: " + str(train_x.shape))
print ("test_x's shape: " + str(test_x.shape))
print ("train_y's shape: " + str(train_y.shape))
print ("test_y's shape: " + str(test_y.shape))
# Out:
# train_x's shape: (209, 12288)
# test_x's shape: (50, 12288)
# train_y's shape: (209, 1)
# test_y's shape: (50, 1)

# %% [markdown]
# ###3- Build your neural network ###
# Now, we are going to use the skills in the first module to build our neural network.
#
# Excep the input layer, you can use
#
# `tf.keras.layers.Dense(20,activation='relu',
#                             kernel_initializer='glorot_uniform',
#                             bias_initializer='zeros')`
#
# to build the layers. In this example, we have 20 neurons in this layer, use 'relu' as the activation function, initialize our weight randomly using 'glorot_uniform', and our bias is initialized to be 'zeros'.
#
# First, we will need an input layer. How many neurons will you need in the input layer? Hint: how many elements does every training input have?
#
# Second, we will build several hidden layers. You are free to choose the number of neurons in every hidden layer.
#
# Last, we will build the output layer. How many neurons will you need in the output layer? Which activation function is more suitale in this problem? Hint: how many elements does every training output have? What is the range of the training output?

# %%
tf.random.set_seed(1) # we fixed the seed of the random number generator, so every time running this code, we can have the same results.

# start your code here
cat_model=tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(12288,)), # how many elements are there in every training image?
    tf.keras.layers.Dense(20,activation='relu', # in layer 1, we will have 20 neurons and use 'relu' as the activation function
                            kernel_initializer='glorot_uniform', # we will randomly choose the initial weight using the 'glorot_uniform' method
                            bias_initializer='zeros'), # we will initialize all bias to be zeros.
    #please follow the example of layer 1 to add more hidden layers here. 
    tf.keras.layers.Dense(20,activation='relu', # in layer 1, we will have 20 neurons and use 'relu' as the activation function
                            kernel_initializer='glorot_uniform', # we will randomly choose the initial weight using the 'glorot_uniform' method
                            bias_initializer='zeros'), # we will initialize all bias to be zeros.
    tf.keras.layers.Dense(30,activation='relu', # in layer 1, we will have 20 neurons and use 'relu' as the activation function
                            kernel_initializer='glorot_uniform', # we will randomly choose the initial weight using the 'glorot_uniform' method
                            bias_initializer='zeros'), # we will initialize all bias to be zeros.
    tf.keras.layers.Dense(20,activation='relu', # in layer 1, we will have 20 neurons and use 'relu' as the activation function
                            kernel_initializer='glorot_uniform', # we will randomly choose the initial weight using the 'glorot_uniform' method
                            bias_initializer='zeros'), # we will initialize all bias to be zeros.
    # End adding hidden layers                    
    tf.keras.layers.Dense(1,activation='sigmoid', # how many elements are there in every training output
                            kernel_initializer='glorot_uniform',
                            bias_initializer='zeros'),
])
# end your code here
cat_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 20)                245780
#
#  dense_3 (Dense)             (None, 20)                420
#
#  dense_4 (Dense)             (None, 30)                630
#
#  dense_5 (Dense)             (None, 20)                620
#
#  dense_6 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 247,471
# Trainable params: 247,471
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, let's compile the model. When comiling your model, you will need to specify the optimizer, the loss function, and the metrics.
#
# For optimizers, the most popular ones are 'Adam' and its derivatives. You can also try 'RMSprop' and 'SGD' to see which one works better for you. You might need adjust the learning rate to acceperate the training process.
#
# For loss functions, our problem is a two-class classification problem. The most popular loss function would be 'BinaryCrossentropy'. If this is a multiple-class classification problem, you probably want to try 'CategoricalCrossentropy' or 'SparseCategoricalCrossentropy'.
#
# For the metrics, we want to know the accuracy of our model. Therefore, I would recommend 'accuracy'.

# %%
# start your code here
cat_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),  # Optimizer. Please change 'None' to some meaningful learning rate which is usually <1
    # Loss function to minimize
    loss=tf.keras.losses.BinaryCrossentropy(),
    # List of metrics to monitor
    metrics=['accuracy'],
                 )
# end your code here

# %% [markdown]
# It's time to train.
#
# We can plot training history. It can help us to adjust the parameters.
#
# If the training loss increases, we may want to decrease the `learning_rate`.
#
# If the training loss has large vibration, we may want to decrease the `learning_rate`.
#
# If the training loss decreases too slowly, we need to increase `learning_rate`.
#
# If the training loss decreases at a good speed, but ends up large, we may want to increase the epoch number.

# %%
# start your code here
history = cat_model.fit(
    train_x, # input data
    train_y, # real output data
    batch_size=10,
  #  validation_split=0.1, # this number is usually betwwen 0 and 0.3. It is the portion used as validation data, 
    epochs=200, # how many iterations do you want to train your model? Your data will be reused to train the model for the number of epochs. I trained 5 min for this model
)
# end your code here. 
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss','val_loss'])
# Out:
# Epoch 1/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9522
# Epoch 2/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9522
# Epoch 3/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1456 - accuracy: 0.9522
# Epoch 4/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1456 - accuracy: 0.9522
# Epoch 5/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1457 - accuracy: 0.9522
# Epoch 6/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1456 - accuracy: 0.9522
# Epoch 7/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1459 - accuracy: 0.9522
# Epoch 8/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1457 - accuracy: 0.9522
# Epoch 9/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1456 - accuracy: 0.9522
# Epoch 10/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1459 - accuracy: 0.9522
# Epoch 11/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9522
# Epoch 12/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1459 - accuracy: 0.9522
# Epoch 13/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9522
# Epoch 14/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1458 - accuracy: 0.9522
# Epoch 15/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1460 - accuracy: 0.9522
# Epoch 16/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1456 - accuracy: 0.9522
# Epoch 17/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9522
# Epoch 18/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9522
# Epoch 19/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1459 - accuracy: 0.9522
# Epoch 20/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1458 - accuracy: 0.9522
# Epoch 21/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9522
# Epoch 22/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1456 - accuracy: 0.9522
# Epoch 23/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1463 - accuracy: 0.9522
# Epoch 24/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1457 - accuracy: 0.9522
# Epoch 25/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1456 - accuracy: 0.9522
# Epoch 26/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1459 - accuracy: 0.9522
# Epoch 27/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1459 - accuracy: 0.9522
# Epoch 28/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9522
# Epoch 29/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.1457 - accuracy: 0.9522
# Epoch 30/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1456 - accuracy: 0.9522
# Epoch 31/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1461 - accuracy: 0.9522
# Epoch 32/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9522
# Epoch 33/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1458 - accuracy: 0.9522
# Epoch 34/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1463 - accuracy: 0.9522
# Epoch 35/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1455 - accuracy: 0.9522
# Epoch 36/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1456 - accuracy: 0.9522
# Epoch 37/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1458 - accuracy: 0.9522
# Epoch 38/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1456 - accuracy: 0.9522
# Epoch 39/200
# 21/21 [==============================] - 0s 4ms/step - loss: 1.0213 - accuracy: 0.6029
# Epoch 40/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.7735 - accuracy: 0.5550
# Epoch 41/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6118 - accuracy: 0.6746
# Epoch 42/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.5492 - accuracy: 0.7033
# Epoch 43/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.5654 - accuracy: 0.6699
# Epoch 44/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.5424 - accuracy: 0.7129
# Epoch 45/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6682 - accuracy: 0.4833
# Epoch 46/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.5680 - accuracy: 0.6268
# Epoch 47/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5099 - accuracy: 0.6555
# Epoch 48/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4888 - accuracy: 0.6890
# Epoch 49/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4907 - accuracy: 0.7321
# Epoch 50/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4867 - accuracy: 0.7225
# Epoch 51/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4697 - accuracy: 0.7321
# Epoch 52/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4740 - accuracy: 0.7560
# Epoch 53/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4808 - accuracy: 0.7560
# Epoch 54/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4792 - accuracy: 0.7368
# Epoch 55/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4305 - accuracy: 0.7656
# Epoch 56/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4145 - accuracy: 0.7799
# Epoch 57/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4219 - accuracy: 0.7799
# Epoch 58/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3907 - accuracy: 0.7799
# Epoch 59/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3742 - accuracy: 0.8086
# Epoch 60/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3895 - accuracy: 0.7895
# Epoch 61/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5431 - accuracy: 0.6172
# Epoch 62/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.6893 - accuracy: 0.4354
# Epoch 63/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.5791 - accuracy: 0.5885
# Epoch 64/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4311 - accuracy: 0.6555
# Epoch 65/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3886 - accuracy: 0.7368
# Epoch 66/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4121 - accuracy: 0.7799
# Epoch 67/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4002 - accuracy: 0.7847
# Epoch 68/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4403 - accuracy: 0.7608
# Epoch 69/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4233 - accuracy: 0.7608
# Epoch 70/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4444 - accuracy: 0.7416
# Epoch 71/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3645 - accuracy: 0.8134
# Epoch 72/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3559 - accuracy: 0.8230
# Epoch 73/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3425 - accuracy: 0.8182
# Epoch 74/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3539 - accuracy: 0.8182
# Epoch 75/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3218 - accuracy: 0.8421
# Epoch 76/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3101 - accuracy: 0.8565
# Epoch 77/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.3349 - accuracy: 0.8373
# Epoch 78/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4400 - accuracy: 0.7751
# Epoch 79/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4404 - accuracy: 0.7799
# Epoch 80/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3853 - accuracy: 0.7943
# Epoch 81/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3596 - accuracy: 0.8278
# Epoch 82/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3938 - accuracy: 0.7943
# Epoch 83/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3165 - accuracy: 0.8325
# Epoch 84/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3112 - accuracy: 0.8565
# Epoch 85/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3122 - accuracy: 0.8517
# Epoch 86/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3255 - accuracy: 0.8421
# Epoch 87/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2922 - accuracy: 0.8708
# Epoch 88/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2852 - accuracy: 0.8708
# Epoch 89/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2810 - accuracy: 0.8708
# Epoch 90/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2848 - accuracy: 0.8660
# Epoch 91/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2907 - accuracy: 0.8660
# Epoch 92/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2702 - accuracy: 0.8804
# Epoch 93/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3201 - accuracy: 0.8469
# Epoch 94/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3028 - accuracy: 0.8517
# Epoch 95/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3685 - accuracy: 0.8182
# Epoch 96/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3459 - accuracy: 0.8278
# Epoch 97/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3412 - accuracy: 0.8373
# Epoch 98/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3485 - accuracy: 0.8182
# Epoch 99/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2673 - accuracy: 0.8804
# Epoch 100/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2703 - accuracy: 0.8756
# Epoch 101/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2852 - accuracy: 0.8708
# Epoch 102/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3038 - accuracy: 0.8612
# Epoch 103/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3048 - accuracy: 0.8756
# Epoch 104/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2991 - accuracy: 0.8565
# Epoch 105/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2612 - accuracy: 0.8900
# Epoch 106/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2851 - accuracy: 0.8612
# Epoch 107/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3076 - accuracy: 0.8517
# Epoch 108/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2749 - accuracy: 0.8756
# Epoch 109/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2519 - accuracy: 0.8947
# Epoch 110/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2827 - accuracy: 0.8756
# Epoch 111/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2531 - accuracy: 0.8900
# Epoch 112/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2384 - accuracy: 0.8995
# Epoch 113/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2350 - accuracy: 0.9043
# Epoch 114/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2349 - accuracy: 0.9043
# Epoch 115/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2850 - accuracy: 0.8660
# Epoch 116/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2504 - accuracy: 0.8947
# Epoch 117/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2393 - accuracy: 0.8995
# Epoch 118/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3373 - accuracy: 0.8325
# Epoch 119/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4862 - accuracy: 0.7656
# Epoch 120/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4786 - accuracy: 0.7129
# Epoch 121/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3333 - accuracy: 0.8325
# Epoch 122/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3009 - accuracy: 0.8612
# Epoch 123/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2733 - accuracy: 0.8804
# Epoch 124/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2655 - accuracy: 0.8852
# Epoch 125/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2825 - accuracy: 0.8660
# Epoch 126/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3230 - accuracy: 0.8421
# Epoch 127/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2509 - accuracy: 0.8947
# Epoch 128/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2687 - accuracy: 0.8756
# Epoch 129/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2667 - accuracy: 0.8804
# Epoch 130/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2497 - accuracy: 0.8947
# Epoch 131/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2580 - accuracy: 0.8900
# Epoch 132/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2538 - accuracy: 0.8804
# Epoch 133/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2432 - accuracy: 0.8995
# Epoch 134/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2339 - accuracy: 0.9043
# Epoch 135/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2429 - accuracy: 0.8947
# Epoch 136/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2817 - accuracy: 0.8660
# Epoch 137/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3077 - accuracy: 0.8612
# Epoch 138/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2623 - accuracy: 0.8804
# Epoch 139/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2758 - accuracy: 0.8756
# Epoch 140/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2392 - accuracy: 0.8995
# Epoch 141/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2605 - accuracy: 0.8852
# Epoch 142/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2464 - accuracy: 0.8852
# Epoch 143/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2472 - accuracy: 0.8947
# Epoch 144/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2478 - accuracy: 0.8947
# Epoch 145/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2222 - accuracy: 0.9091
# Epoch 146/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2472 - accuracy: 0.8900
# Epoch 147/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2513 - accuracy: 0.8900
# Epoch 148/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2407 - accuracy: 0.8995
# Epoch 149/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2330 - accuracy: 0.9091
# Epoch 150/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2086 - accuracy: 0.9234
# Epoch 151/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2239 - accuracy: 0.9139
# Epoch 152/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2343 - accuracy: 0.8995
# Epoch 153/200
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2311 - accuracy: 0.9091
# Epoch 154/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2616 - accuracy: 0.8900
# Epoch 155/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.8565
# Epoch 156/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4010 - accuracy: 0.8182
# Epoch 157/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3208 - accuracy: 0.8469
# Epoch 158/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2407 - accuracy: 0.9043
# Epoch 159/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2238 - accuracy: 0.9043
# Epoch 160/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2275 - accuracy: 0.9091
# Epoch 161/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2067 - accuracy: 0.9234
# Epoch 162/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2078 - accuracy: 0.9187
# Epoch 163/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2040 - accuracy: 0.9187
# Epoch 164/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1973 - accuracy: 0.9282
# Epoch 165/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2245 - accuracy: 0.9091
# Epoch 166/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2023 - accuracy: 0.9234
# Epoch 167/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1983 - accuracy: 0.9282
# Epoch 168/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2038 - accuracy: 0.9234
# Epoch 169/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2023 - accuracy: 0.9234
# Epoch 170/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2161 - accuracy: 0.9139
# Epoch 171/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2010 - accuracy: 0.9234
# Epoch 172/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2144 - accuracy: 0.9139
# Epoch 173/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2102 - accuracy: 0.9187
# Epoch 174/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2406 - accuracy: 0.9043
# Epoch 175/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2141 - accuracy: 0.9139
# Epoch 176/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2438 - accuracy: 0.8947
# Epoch 177/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2034 - accuracy: 0.9187
# Epoch 178/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2121 - accuracy: 0.9187
# Epoch 179/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2108 - accuracy: 0.9139
# Epoch 180/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2041 - accuracy: 0.9234
# Epoch 181/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2009 - accuracy: 0.9234
# Epoch 182/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2085 - accuracy: 0.9187
# Epoch 183/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2279 - accuracy: 0.9043
# Epoch 184/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2115 - accuracy: 0.9187
# Epoch 185/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1991 - accuracy: 0.9234
# Epoch 186/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1931 - accuracy: 0.9282
# Epoch 187/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1936 - accuracy: 0.9282
# Epoch 188/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2282 - accuracy: 0.9139
# Epoch 189/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3148 - accuracy: 0.8660
# Epoch 190/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2297 - accuracy: 0.9091
# Epoch 191/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2014 - accuracy: 0.9234
# Epoch 192/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1950 - accuracy: 0.9282
# Epoch 193/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2023 - accuracy: 0.9234
# Epoch 194/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2221 - accuracy: 0.9139
# Epoch 195/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1943 - accuracy: 0.9282
# Epoch 196/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2022 - accuracy: 0.9234
# Epoch 197/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1937 - accuracy: 0.9282
# Epoch 198/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2007 - accuracy: 0.9234
# Epoch 199/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2022 - accuracy: 0.9234
# Epoch 200/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2033 - accuracy: 0.9187
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-0a0b5ae34478> in <module>()
#      10 plt.figure()
#      11 plt.plot(history.history['loss'])
# ---> 12 plt.plot(history.history['val_loss'])
#      13 plt.legend(['loss','val_loss'])
#
# KeyError: 'val_loss'

# %% [markdown]
# ### 4. test ###
# Let us test their performance using our test dataset. The test dataset is never used to train the models, and reflects the acutual performance of the model when it is used in the general images.
#
# To evaluate the model , we can use
# `cat_model.evaluate(test_x,test_y)`.

# %%
cat_model.evaluate(test_x,test_y)
# Out:
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0231 - accuracy: 0.7200
# [2.0231173038482666, 0.7200000286102295]

# %% [markdown]
# The expected accuracy is higher than 0.7. If the accuracy is lower than 0.7, you may want to increase the epoch number, adjust the learning rate, and the regularizer weight, to achieve the goal.
#
# For your reference, I trained the model for 5 min to achieve that goal.
#
# If you have achieved the 0.7 goal, I would like to challenge you for the 0.8 accuracy for the test set.

# %% [markdown]
# ### 5- Adding Regularization ###
# After enough training, you probably notice that while the training loss is very small, the validation loss is quite large. This is what we called **low bias high vairance** problem. We have several ways to deal with it,
# 1. L1/L2 regularization,
# 2. drop out, and
# 3. early stop.
#
# I would recommend you try the regularization first, because it's easy to use and usually works.
#
# To add regularization to the network, we only need to specify this option in the 'Dense' layer as follows.
#
# `tf.keras.layers.Dense(20,activation='relu',
#                           kernel_initializer='glorot_uniform',
#                           bias_initializer='zeros',
#                           kernel_regularizer=tf.keras.regularizers.L2(0.01))`
#
# The parameter **kernel_regularizer=tf.keras.regularizers.L2(0.01)** says that we want an 'L2' regularizer with weight 0.01. A higher weight usually can reduce the validation loss more. But if the weight is too large, the training loss might redecus very slowly.

# %%
tf.random.set_seed(1)
cat_model_regu=tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(12288,)),
    tf.keras.layers.Dense(20,activation='relu', # in layer 1, we will have 20 neurons and use 'relu'
                          kernel_initializer='glorot_uniform',# we will randomly choose the initial weight using the 'glorot_uniform' method as the activation function
                          bias_initializer='zeros', # we will initialize all bias to be zeros.
                          kernel_regularizer=tf.keras.regularizers.L2(0.01)), # L2-regularization can be added here
    #please feel free to add more hidden layers with regularizer
    tf.keras.layers.Dense(20,activation='relu', # in layer 1, we will have 20 neurons and use 'relu'
                          kernel_initializer='glorot_uniform',# we will randomly choose the initial weight using the 'glorot_uniform' method as the activation function
                          bias_initializer='zeros', # we will initialize all bias to be zeros.
                          kernel_regularizer=tf.keras.regularizers.L2(0.01)), # L2-regularization can be added here
                 
    # End adding hidden layers 
    tf.keras.layers.Dense(1,activation='sigmoid', 
                            kernel_initializer='glorot_uniform',
                            bias_initializer='zeros', 
                          kernel_regularizer=tf.keras.regularizers.L2(0.01)),
])

cat_model_regu.summary()
# Out:
# Model: "sequential_35"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_99 (Dense)            (None, 20)                245780
#
#  dense_100 (Dense)           (None, 20)                420
#
#  dense_101 (Dense)           (None, 1)                 21
#
# =================================================================
# Total params: 246,221
# Trainable params: 246,221
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, you can compile and train the regularized neural network as before.

# %%
# start your code here
cat_model_regu.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),  # Optimizer please change "None" to some meaningful number here
    # Loss function to minimize
    loss=tf.keras.losses.BinaryCrossentropy(),
    # List of metrics to monitor
    metrics=['accuracy'],
                 )
# end your code here.

# %%
# start your code here
history_regu = cat_model_regu.fit(
    train_x, # input data
    train_y, # real output data
   # validation_split=None, # this number is usually betwwen 0 and 0.3. It is the portion used as validation data, 
   batch_size=5,
    epochs=200, # how many iterations do you want to train your model? Your data will be reused to train the model for the number of epochs. I trained 5 min for this model
)
# end your code here

plt.figure()
plt.plot(history_regu.history['loss'])
plt.plot(history_regu.history['val_loss'])
plt.legend(['loss','val_loss'])
# Out:
# Epoch 1/200
# 42/42 [==============================] - 1s 5ms/step - loss: 1.2866 - accuracy: 0.6077
# Epoch 2/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.2520 - accuracy: 0.6555
# Epoch 3/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.2491 - accuracy: 0.6459
# Epoch 4/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.2281 - accuracy: 0.6651
# Epoch 5/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.2142 - accuracy: 0.6651
# Epoch 6/200
# 42/42 [==============================] - 0s 5ms/step - loss: 1.2165 - accuracy: 0.6746
# Epoch 7/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.2106 - accuracy: 0.6986
# Epoch 8/200
# 42/42 [==============================] - 0s 5ms/step - loss: 1.1935 - accuracy: 0.6794
# Epoch 9/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.1808 - accuracy: 0.6938
# Epoch 10/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.1739 - accuracy: 0.7177
# Epoch 11/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.1597 - accuracy: 0.7225
# Epoch 12/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.1531 - accuracy: 0.7081
# Epoch 13/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.1472 - accuracy: 0.7273
# Epoch 14/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.1257 - accuracy: 0.7368
# Epoch 15/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.1327 - accuracy: 0.7225
# Epoch 16/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.1080 - accuracy: 0.7368
# Epoch 17/200
# 42/42 [==============================] - 0s 5ms/step - loss: 1.1234 - accuracy: 0.7464
# Epoch 18/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.1096 - accuracy: 0.7416
# Epoch 19/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.0852 - accuracy: 0.7799
# Epoch 20/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.0808 - accuracy: 0.7656
# Epoch 21/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.0685 - accuracy: 0.7847
# Epoch 22/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.0737 - accuracy: 0.8134
# Epoch 23/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.0424 - accuracy: 0.8134
# Epoch 24/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.0501 - accuracy: 0.8421
# Epoch 25/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.0475 - accuracy: 0.8182
# Epoch 26/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.0283 - accuracy: 0.8373
# Epoch 27/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.0108 - accuracy: 0.8230
# Epoch 28/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.0121 - accuracy: 0.8230
# Epoch 29/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.9992 - accuracy: 0.8612
# Epoch 30/200
# 42/42 [==============================] - 0s 4ms/step - loss: 1.0074 - accuracy: 0.8278
# Epoch 31/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.9999 - accuracy: 0.8278
# Epoch 32/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.9930 - accuracy: 0.8421
# Epoch 33/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.9788 - accuracy: 0.8756
# Epoch 34/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.9709 - accuracy: 0.8469
# Epoch 35/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.9790 - accuracy: 0.8852
# Epoch 36/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.9792 - accuracy: 0.8612
# Epoch 37/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.9575 - accuracy: 0.8852
# Epoch 38/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.9490 - accuracy: 0.8660
# Epoch 39/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.9654 - accuracy: 0.8565
# Epoch 40/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.9310 - accuracy: 0.8947
# Epoch 41/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.9252 - accuracy: 0.8852
# Epoch 42/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.9235 - accuracy: 0.8756
# Epoch 43/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8984 - accuracy: 0.8947
# Epoch 44/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.9263 - accuracy: 0.8565
# Epoch 45/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.9119 - accuracy: 0.8995
# Epoch 46/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8998 - accuracy: 0.9043
# Epoch 47/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8894 - accuracy: 0.8804
# Epoch 48/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8734 - accuracy: 0.9091
# Epoch 49/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8734 - accuracy: 0.9187
# Epoch 50/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8866 - accuracy: 0.8900
# Epoch 51/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8686 - accuracy: 0.9091
# Epoch 52/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8544 - accuracy: 0.9282
# Epoch 53/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8500 - accuracy: 0.9330
# Epoch 54/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8564 - accuracy: 0.9139
# Epoch 55/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8510 - accuracy: 0.9330
# Epoch 56/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8352 - accuracy: 0.9139
# Epoch 57/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.8387 - accuracy: 0.9378
# Epoch 58/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8374 - accuracy: 0.9282
# Epoch 59/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8083 - accuracy: 0.9522
# Epoch 60/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.8218 - accuracy: 0.9474
# Epoch 61/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8093 - accuracy: 0.9474
# Epoch 62/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.8084 - accuracy: 0.9378
# Epoch 63/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8043 - accuracy: 0.9378
# Epoch 64/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.8015 - accuracy: 0.9426
# Epoch 65/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7894 - accuracy: 0.9569
# Epoch 66/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7869 - accuracy: 0.9569
# Epoch 67/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7903 - accuracy: 0.9426
# Epoch 68/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7826 - accuracy: 0.9569
# Epoch 69/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7879 - accuracy: 0.9426
# Epoch 70/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7632 - accuracy: 0.9569
# Epoch 71/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7604 - accuracy: 0.9569
# Epoch 72/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7675 - accuracy: 0.9522
# Epoch 73/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7701 - accuracy: 0.9713
# Epoch 74/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7556 - accuracy: 0.9713
# Epoch 75/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.7356 - accuracy: 0.9809
# Epoch 76/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7552 - accuracy: 0.9713
# Epoch 77/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7561 - accuracy: 0.9569
# Epoch 78/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7447 - accuracy: 0.9665
# Epoch 79/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.7477 - accuracy: 0.9617
# Epoch 80/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7531 - accuracy: 0.9426
# Epoch 81/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7344 - accuracy: 0.9665
# Epoch 82/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7203 - accuracy: 0.9761
# Epoch 83/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7251 - accuracy: 0.9761
# Epoch 84/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7292 - accuracy: 0.9617
# Epoch 85/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7228 - accuracy: 0.9809
# Epoch 86/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7084 - accuracy: 0.9904
# Epoch 87/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7131 - accuracy: 0.9856
# Epoch 88/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6989 - accuracy: 0.9904
# Epoch 89/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7007 - accuracy: 0.9904
# Epoch 90/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.7067 - accuracy: 0.9809
# Epoch 91/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7067 - accuracy: 0.9809
# Epoch 92/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.7029 - accuracy: 0.9809
# Epoch 93/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6905 - accuracy: 0.9856
# Epoch 94/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6842 - accuracy: 0.9904
# Epoch 95/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.9952
# Epoch 96/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.6733 - accuracy: 0.9952
# Epoch 97/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6789 - accuracy: 0.9904
# Epoch 98/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6701 - accuracy: 0.9952
# Epoch 99/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.6688 - accuracy: 0.9952
# Epoch 100/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6724 - accuracy: 1.0000
# Epoch 101/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6721 - accuracy: 0.9856
# Epoch 102/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6714 - accuracy: 0.9952
# Epoch 103/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6603 - accuracy: 0.9904
# Epoch 104/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6564 - accuracy: 0.9952
# Epoch 105/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.6642 - accuracy: 0.9904
# Epoch 106/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.6559 - accuracy: 0.9952
# Epoch 107/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.6580 - accuracy: 0.9904
# Epoch 108/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6479 - accuracy: 0.9952
# Epoch 109/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6525 - accuracy: 0.9952
# Epoch 110/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6434 - accuracy: 0.9952
# Epoch 111/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6425 - accuracy: 0.9952
# Epoch 112/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6464 - accuracy: 0.9952
# Epoch 113/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6366 - accuracy: 0.9952
# Epoch 114/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6446 - accuracy: 0.9952
# Epoch 115/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6374 - accuracy: 0.9952
# Epoch 116/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.6381 - accuracy: 1.0000
# Epoch 117/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6348 - accuracy: 0.9952
# Epoch 118/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6328 - accuracy: 0.9952
# Epoch 119/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.6300 - accuracy: 0.9952
# Epoch 120/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6277 - accuracy: 1.0000
# Epoch 121/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6279 - accuracy: 0.9952
# Epoch 122/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6249 - accuracy: 0.9952
# Epoch 123/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6240 - accuracy: 0.9952
# Epoch 124/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6199 - accuracy: 0.9952
# Epoch 125/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6191 - accuracy: 0.9952
# Epoch 126/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6196 - accuracy: 0.9952
# Epoch 127/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6120 - accuracy: 0.9952
# Epoch 128/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6125 - accuracy: 0.9952
# Epoch 129/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6153 - accuracy: 1.0000
# Epoch 130/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.6107 - accuracy: 0.9952
# Epoch 131/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6100 - accuracy: 0.9952
# Epoch 132/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6034 - accuracy: 1.0000
# Epoch 133/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6134 - accuracy: 0.9952
# Epoch 134/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6065 - accuracy: 1.0000
# Epoch 135/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6021 - accuracy: 1.0000
# Epoch 136/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6004 - accuracy: 1.0000
# Epoch 137/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.6071 - accuracy: 0.9952
# Epoch 138/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5962 - accuracy: 1.0000
# Epoch 139/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5992 - accuracy: 1.0000
# Epoch 140/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5968 - accuracy: 0.9952
# Epoch 141/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5912 - accuracy: 1.0000
# Epoch 142/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5941 - accuracy: 0.9952
# Epoch 143/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.5915 - accuracy: 1.0000
# Epoch 144/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5925 - accuracy: 1.0000
# Epoch 145/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5883 - accuracy: 0.9952
# Epoch 146/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5864 - accuracy: 1.0000
# Epoch 147/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5866 - accuracy: 1.0000
# Epoch 148/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5876 - accuracy: 0.9952
# Epoch 149/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5834 - accuracy: 1.0000
# Epoch 150/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5841 - accuracy: 0.9952
# Epoch 151/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5826 - accuracy: 1.0000
# Epoch 152/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5811 - accuracy: 0.9952
# Epoch 153/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5798 - accuracy: 1.0000
# Epoch 154/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5871 - accuracy: 0.9904
# Epoch 155/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5784 - accuracy: 0.9952
# Epoch 156/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5792 - accuracy: 0.9952
# Epoch 157/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5761 - accuracy: 0.9952
# Epoch 158/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5744 - accuracy: 1.0000
# Epoch 159/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5736 - accuracy: 0.9952
# Epoch 160/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5728 - accuracy: 1.0000
# Epoch 161/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5714 - accuracy: 1.0000
# Epoch 162/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5711 - accuracy: 0.9952
# Epoch 163/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5691 - accuracy: 1.0000
# Epoch 164/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5662 - accuracy: 1.0000
# Epoch 165/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5700 - accuracy: 1.0000
# Epoch 166/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5652 - accuracy: 1.0000
# Epoch 167/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5641 - accuracy: 0.9952
# Epoch 168/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5614 - accuracy: 1.0000
# Epoch 169/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5650 - accuracy: 0.9952
# Epoch 170/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5610 - accuracy: 1.0000
# Epoch 171/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5609 - accuracy: 0.9952
# Epoch 172/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5582 - accuracy: 1.0000
# Epoch 173/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5572 - accuracy: 1.0000
# Epoch 174/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5567 - accuracy: 1.0000
# Epoch 175/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5560 - accuracy: 1.0000
# Epoch 176/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5560 - accuracy: 0.9952
# Epoch 177/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5537 - accuracy: 1.0000
# Epoch 178/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5509 - accuracy: 1.0000
# Epoch 179/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5503 - accuracy: 1.0000
# Epoch 180/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5500 - accuracy: 1.0000
# Epoch 181/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5490 - accuracy: 1.0000
# Epoch 182/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5509 - accuracy: 1.0000
# Epoch 183/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5479 - accuracy: 1.0000
# Epoch 184/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5471 - accuracy: 1.0000
# Epoch 185/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5466 - accuracy: 1.0000
# Epoch 186/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5462 - accuracy: 1.0000
# Epoch 187/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5451 - accuracy: 1.0000
# Epoch 188/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5424 - accuracy: 1.0000
# Epoch 189/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5418 - accuracy: 1.0000
# Epoch 190/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5424 - accuracy: 1.0000
# Epoch 191/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5401 - accuracy: 1.0000
# Epoch 192/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5379 - accuracy: 1.0000
# Epoch 193/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5409 - accuracy: 1.0000
# Epoch 194/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5383 - accuracy: 1.0000
# Epoch 195/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5382 - accuracy: 1.0000
# Epoch 196/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5367 - accuracy: 1.0000
# Epoch 197/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5351 - accuracy: 1.0000
# Epoch 198/200
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5341 - accuracy: 1.0000
# Epoch 199/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5343 - accuracy: 1.0000
# Epoch 200/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5348 - accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-291-375f4fadc038> in <module>()
#      11 plt.figure()
#      12 plt.plot(history_regu.history['loss'])
# ---> 13 plt.plot(history_regu.history['val_loss'])
#      14 plt.legend(['loss','val_loss'])
#
# KeyError: 'val_loss'

# %% [markdown]
# After the training, we can evaluate the regularized NN use the following command.

# %%
cat_model_regu.evaluate(test_x,test_y)
# Out:
# 2/2 [==============================] - 0s 13ms/step - loss: 1.0885 - accuracy: 0.7600
# [1.0885013341903687, 0.7599999904632568]

# %% [markdown]
# The expected accuracy is highter than 0.8.
